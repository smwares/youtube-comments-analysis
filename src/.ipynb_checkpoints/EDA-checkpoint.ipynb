# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
all_comments_df = pd.read_csv('../data/comments.csv')

# %%
all_comments_df
# Out:
#                                                comment  \
# 0                                         clitti media
# 1                                spot on sarr tank you
# 2                            SAAAAAAAAAAAAAAAAAAAAAAAR
# 3    So that’s what pajeet means. I just learned ab...
# 4    Guys don't ever disable the comments section. ...
# ..                                                 ...
# 750  @@poolbadshah4948  toh beta woh aise kaam hi k...
# 751               @@notwhoyouthink2415quite Pedo lover
# 752  @@poolbadshah4948I’m pretty sure this was star...
# 753  yes saaar... VIKRAMADITYA EMPIRE RULE THE WORL...
# 754  @@themanofachild1546 Pakistanis say “sir“ as w...
#
#                                             comment_id  \
# 0                           Ugxf_DS6dr_-rWX4Lj54AaABAg
# 1                           UgyptLZU6sOxVn328FN4AaABAg
# 2                           UgwSA4uvZj9G1HsZx3Z4AaABAg
# 3                           UgyPGcQs55TMbh1ImNV4AaABAg
# 4                           UgxhMwJ6rGoEXFKWmDR4AaABAg
# ..                                                 ...
# 750  UgzyAGDt7HEXd91TIu94AaABAg.9xjppUL6AK_A-OGbF4-mJN
# 751  UgzyAGDt7HEXd91TIu94AaABAg.9xjppUL6AK_A-dy5-ZeRVn
# 752  UgzyAGDt7HEXd91TIu94AaABAg.9xjppUL6AK_A18-blIMtUS
# 753  UgzyAGDt7HEXd91TIu94AaABAg.9xjppUL6AK_A1OBNDPS7Yt
# 754  UgzyAGDt7HEXd91TIu94AaABAg.9xjppUL6AK_A1OCMKnXVcu
#
#                  parent_comment                   user  \
# 0                           NaN  @richardc.mongler1029
# 1                           NaN  @ugly_indian_scammer_
# 2                           NaN            @frankw3678
# 3                           NaN               @XGen_23
# 4                           NaN  @uselesshero.official
# ..                          ...                    ...
# 750  UgzyAGDt7HEXd91TIu94AaABAg          @B.E.Y.O.N.D.
# 751  UgzyAGDt7HEXd91TIu94AaABAg              @Argon369
# 752  UgzyAGDt7HEXd91TIu94AaABAg             @Frosty_V0
# 753  UgzyAGDt7HEXd91TIu94AaABAg    @themanofachild1546
# 754  UgzyAGDt7HEXd91TIu94AaABAg             @Frosty_V0
#
#                                            user_avatar  \
# 0    https://yt3.ggpht.com/cvP6xxp8yZ2K8Bn9elJjksfY...
# 1    https://yt3.ggpht.com/YgIAPldF-wv5zqTjxAlkDGSx...
# 2    https://yt3.ggpht.com/ytc/AIdro_mn6vzRsus9QLBj...
# 3    https://yt3.ggpht.com/8VaDX_Wgy15JoylXTaEFUqkY...
# 4    https://yt3.ggpht.com/ytc/AIdro_nabVw9bTnnDdEQ...
# ..                                                 ...
# 750  https://yt3.ggpht.com/qorHq0v_QYpquw-aS0Fn_JKI...
# 751  https://yt3.ggpht.com/tBYDUTcjmluS59xSpQKbSa1r...
# 752  https://yt3.ggpht.com/1hhf3-NxR2CJd564V50twpQB...
# 753  https://yt3.ggpht.com/ytc/AIdro_lobEygh6O_Bjl7...
# 754  https://yt3.ggpht.com/1hhf3-NxR2CJd564V50twpQB...
#
#                                         user_page               comment_time  \
# 0    http://www.youtube.com/@richardc.mongler1029  2024-04-28 04:17:10+00:00
# 1    http://www.youtube.com/@ugly_indian_scammer_  2024-04-27 19:07:36+00:00
# 2              http://www.youtube.com/@frankw3678  2024-04-26 16:03:34+00:00
# 3                 http://www.youtube.com/@XGen_23  2024-04-26 15:08:35+00:00
# 4    http://www.youtube.com/@uselesshero.official  2024-04-26 06:00:10+00:00
# ..                                            ...                        ...
# 750          http://www.youtube.com/@B.E.Y.O.N.D.  2024-02-04 08:02:36+00:00
# 751              http://www.youtube.com/@Argon369  2024-02-10 19:39:07+00:00
# 752             http://www.youtube.com/@Frosty_V0  2024-03-18 17:29:04+00:00
# 753    http://www.youtube.com/@themanofachild1546  2024-03-25 00:19:39+00:00
# 754             http://www.youtube.com/@Frosty_V0  2024-03-25 00:28:16+00:00
#
#      likes  replies
# 0        1        0
# 1        1        0
# 2        1        0
# 3        0        0
# 4        1        3
# ..     ...      ...
# 750      0        0
# 751      0        0
# 752      0        0
# 753      1        0
# 754      0        0
#
# [755 rows x 9 columns]

# %%
all_comments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 755 entries, 0 to 754
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   comment         755 non-null    object
#  1   comment_id      755 non-null    object
#  2   parent_comment  582 non-null    object
#  3   user            755 non-null    object
#  4   user_avatar     755 non-null    object
#  5   user_page       755 non-null    object
#  6   comment_time    755 non-null    object
#  7   likes           755 non-null    int64
#  8   replies         755 non-null    int64
# dtypes: int64(2), object(7)
# memory usage: 53.2+ KB

# %%
# convert the comment_time column into a datetime format
all_comments_df['comment_time'] = pd.to_datetime(all_comments_df['comment_time'])

# %%
# convert certain columns to save space and perform quicker
all_comments_df = all_comments_df.astype({'likes': 'int32', 'replies': 'int32'})

# %%
all_comments_df['user'].value_counts()
# Out:
# user
# @asingha94                        188
# @Vic67s                            38
# @rexk                              36
# @RyzenRTX89                        19
# @user-us6ji2sl3c                   13
#                                  ...
# @JaimeG88                           1
# @GodHimself-bp3xw                   1
# @adahepper2665                      1
# @FROMTHERIVERTOTHESEA-remember      1
# @richardc.mongler1029               1
# Name: count, Length: 258, dtype: int64

# %%
all_comments_df.groupby(all_comments_df['comment_time'].dt.date).count()['comment'].plot(figsize=(20,8))
plt.show()

# %%
# function to print some visualizations of a user's comments
def user_details(username, comments_df):
    user_comments = comments_df[comments_df['user'] == username].drop('user', axis=1)
    
    # create a DataFrame that only contains the hours of the day
    comments_per_hour = pd.DataFrame({'comment_time': range(24)})
    
    # create a DataFrame that has the hour of the day column and a comment count column by grouping by hour of day, then counting the comments for each hour
    user_comments_per_hour = user_comments.groupby(all_comments_df['comment_time'].dt.hour).count()['comment'].reset_index()
    
    # add the comments per hour column by merging the two DataFrames
    comments_per_hour = pd.merge(comments_per_hour, user_comments_per_hour, on='comment_time', how='outer').fillna(value=0)
    
    # plot a bar graph
    sns.set_style('darkgrid', rc={'grid.color': '.6', 'grid.linestyle': ':', 'xtick.bottom': True, 'ytick.left': True})
    
    fig, ax = plt.subplots(figsize=(16, 8))
    sns.barplot(comments_per_hour, x='comment_time', y='comment')
    ax.set(xlabel = 'Hour of Day', ylabel='Number of Comments', title='Number of Comments Per Hour of Day')
    #ax.set_yticks(range(0,51,5))
    plt.show()
    
    # create a DataFrame that has the number of comments per day
    user_comments_per_day = user_comments.groupby(user_comments['comment_time'].dt.date).count()['comment'].reset_index()
    
    # convert column back to datetime since the column created after the index was reset was converted to an object dtype
    user_comments_per_day['comment_time'] = pd.to_datetime(user_comments_per_day['comment_time'])
    
    # get the earliest and latest dates that the user posted comments on
    min_date = pd.Timestamp(min(user_comments_per_day['comment_time']))
    max_date = pd.Timestamp(max(user_comments_per_day['comment_time']))
    
    #create a range of dates
    date_range = pd.date_range(start=min_date, end=max_date, inclusive='both', freq='D')
    
    # create a DataFrame containing only a range of the dates
    comments_per_day = pd.DataFrame({'comment_time': date_range})
    
    # add the comments per day by merging the two DataFrames
    comments_per_day = pd.merge(comments_per_day, user_comments_per_day, on='comment_time', how='outer').fillna(value=0)
    
    # plot a line graph
    fig, ax = plt.subplots(figsize=(16, 8))
    sns.lineplot(comments_per_day, x='comment_time', y='comment')
    ax.set(xlabel = 'Date', ylabel='Number of Comments', title='Number of Comments Per Day')
    plt.xticks(rotation=45, ha='right')
    plt.show()

# %%
user_details('@asingha94', all_comments_df)
