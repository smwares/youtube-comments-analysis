# %%
import os
import numpy as np
import pandas as pd
from dotenv import load_dotenv
from googleapiclient.discovery import build
from pprint import pprint

# %%
# get the API key from the .env file
load_dotenv()
api_key = os.getenv('API_KEY')

# %%
# insert user ID to extract user info from (this would be the text that comes after 'https://www.youtube.com/')
userId = '@asingha94'

# initiate the YouTube client
youtube = build(serviceName='youtube', version='v3', developerKey=api_key)

part_list = ['brandingSettings', 'contentDetails', 'contentOwnerDetails','id', 'localizations', 'snippet', 'statistics', 'status', 'topicDetails']

# create a request to get the parent comments, then save the response
for part in part_list:
    request = youtube.channels().list(part=part, forHandle=userId, maxResults=50)
    response = request.execute()
    print('\n' + '-'*50, '\n', part, '\n' + '-'*50 + '\n')
    pprint(response)
# Out:
# --------------------------------------------------
#  brandingSettings
# --------------------------------------------------
#
# {'etag': 'Hznj6EeSR_0wARAzmrfuN1rg-4M',
#  'items': [{'brandingSettings': {'channel': {'country': 'IN',
#                                              'keywords': 'Vertrex gaming '
#                                                          'vertex paladin '
#                                                          'rainbow six siege '
#                                                          'vertex "vertex '
#                                                          'gaming" paladin '
#                                                          '"paladin live"',
#                                              'title': 'Numero'}},
#             'etag': 'GL2PMI6lmgL387hpMqfxSZrQvOY',
#             'id': 'UChU6-_uA2zJPuEPB6S0QtlQ',
#             'kind': 'youtube#channel'}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 50, 'totalResults': 1}}
#
# --------------------------------------------------
#  contentDetails
# --------------------------------------------------
#
# {'etag': 'FDVB9mt5ualEzWw5Bv9Ub_F9pKM',
#  'items': [{'contentDetails': {'relatedPlaylists': {'likes': '',
#                                                     'uploads': 'UUhU6-_uA2zJPuEPB6S0QtlQ'}},
#             'etag': 'AvY3m1VdudK4756RN502fYrMkU8',
#             'id': 'UChU6-_uA2zJPuEPB6S0QtlQ',
#             'kind': 'youtube#channel'}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 50, 'totalResults': 1}}
#
# --------------------------------------------------
#  contentOwnerDetails
# --------------------------------------------------
#
# {'etag': 'Yv4SfoZrJ-E_EPKpFB3hqFLoqSs',
#  'items': [{'contentOwnerDetails': {},
#             'etag': 'GtiGSyApTs3b3q8qo8NWuRyFNm4',
#             'id': 'UChU6-_uA2zJPuEPB6S0QtlQ',
#             'kind': 'youtube#channel'}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 50, 'totalResults': 1}}
#
# --------------------------------------------------
#  id
# --------------------------------------------------
#
# {'etag': 'sDWOjDBxt3RNhsjYiL--w5NULJk',
#  'items': [{'etag': '-1ZDGaI4HgosfKuT0wHEGR3h3xk',
#             'id': 'UChU6-_uA2zJPuEPB6S0QtlQ',
#             'kind': 'youtube#channel'}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 50, 'totalResults': 1}}
#
# --------------------------------------------------
#  localizations
# --------------------------------------------------
#
# {'etag': 'sDWOjDBxt3RNhsjYiL--w5NULJk',
#  'items': [{'etag': '-1ZDGaI4HgosfKuT0wHEGR3h3xk',
#             'id': 'UChU6-_uA2zJPuEPB6S0QtlQ',
#             'kind': 'youtube#channel'}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 50, 'totalResults': 1}}
#
# --------------------------------------------------
#  snippet
# --------------------------------------------------
#
# {'etag': 'FErxGiPlliOTAoxbB3TYm5A6ID8',
#  'items': [{'etag': 'srCImxVnCNPeqLGA7PtRy5SefwM',
#             'id': 'UChU6-_uA2zJPuEPB6S0QtlQ',
#             'kind': 'youtube#channel',
#             'snippet': {'country': 'IN',
#                         'customUrl': '@asingha94',
#                         'description': '',
#                         'localized': {'description': '', 'title': 'Numero'},
#                         'publishedAt': '2009-11-20T12:35:59Z',
#                         'thumbnails': {'default': {'height': 88,
#                                                    'url': 'https://yt3.ggpht.com/yfxuvKgoPurr5iNXNPnKLIRML1B7x9uWQtb7uhqIT1x1F046qIzYGduGoKIe9k6ea9R9Lfj4fbc=s88-c-k-c0x00ffffff-no-rj',
#                                                    'width': 88},
#                                        'high': {'height': 800,
#                                                 'url': 'https://yt3.ggpht.com/yfxuvKgoPurr5iNXNPnKLIRML1B7x9uWQtb7uhqIT1x1F046qIzYGduGoKIe9k6ea9R9Lfj4fbc=s800-c-k-c0x00ffffff-no-rj',
#                                                 'width': 800},
#                                        'medium': {'height': 240,
#                                                   'url': 'https://yt3.ggpht.com/yfxuvKgoPurr5iNXNPnKLIRML1B7x9uWQtb7uhqIT1x1F046qIzYGduGoKIe9k6ea9R9Lfj4fbc=s240-c-k-c0x00ffffff-no-rj',
#                                                   'width': 240}},
#                         'title': 'Numero'}}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 50, 'totalResults': 1}}
#
# --------------------------------------------------
#  statistics
# --------------------------------------------------
#
# {'etag': 'vxJx4_lGDPIzGVaeA7CnprEuEQc',
#  'items': [{'etag': 'O30LAv9VGYg672MWX78848rQjAM',
#             'id': 'UChU6-_uA2zJPuEPB6S0QtlQ',
#             'kind': 'youtube#channel',
#             'statistics': {'hiddenSubscriberCount': False,
#                            'subscriberCount': '20',
#                            'videoCount': '39',
#                            'viewCount': '1078'}}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 50, 'totalResults': 1}}
#
# --------------------------------------------------
#  status
# --------------------------------------------------
#
# {'etag': 'Gt868mcqitHPC6DEZpY43O-qdDc',
#  'items': [{'etag': '9l8fCqF7X0XXmhYQbzFOY46HQiA',
#             'id': 'UChU6-_uA2zJPuEPB6S0QtlQ',
#             'kind': 'youtube#channel',
#             'status': {'isLinked': True,
#                        'longUploadsStatus': 'longUploadsUnspecified',
#                        'privacyStatus': 'public'}}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 50, 'totalResults': 1}}
#
# --------------------------------------------------
#  topicDetails
# --------------------------------------------------
#
# {'etag': 'R0JTtMmxRINZ-cnH2kc8WAKKN8Q',
#  'items': [{'etag': 'JLdggfOFBNJLmoerXWQsEKeb8L8',
#             'id': 'UChU6-_uA2zJPuEPB6S0QtlQ',
#             'kind': 'youtube#channel',
#             'topicDetails': {'topicCategories': ['https://en.wikipedia.org/wiki/Action_game',
#                                                  'https://en.wikipedia.org/wiki/Role-playing_video_game',
#                                                  'https://en.wikipedia.org/wiki/Video_game_culture',
#                                                  'https://en.wikipedia.org/wiki/Strategy_video_game',
#                                                  'https://en.wikipedia.org/wiki/Action-adventure_game'],
#                              'topicIds': ['/m/025zzc',
#                                           '/m/0403l3g',
#                                           '/m/0bzvm2',
#                                           '/m/03hf_rm',
#                                           '/m/02ntfj']}}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 50, 'totalResults': 1}}
